# %%
import tensorflow as tf
import os
import pandas as pd
import numpy as np
# Out:
# WARNING:tensorflow:From C:\Users\Admin\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
zip_path = tf.keras.utils.get_file(origin='https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip',
           fname='jena_climate_2009_2016.csv.zip', extract = True)
csv_path, _ = os.path.splitext(zip_path)

# %%
df = pd.read_csv(csv_path)
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0       01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90
# 1       01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28
# 2       01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31
# 3       01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07
# 4       01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04
# ...                     ...       ...       ...       ...          ...
# 420546  31.12.2016 23:20:00   1000.07     -4.05    269.10        -8.13
# 420547  31.12.2016 23:30:00    999.93     -3.35    269.81        -8.06
# 420548  31.12.2016 23:40:00    999.82     -3.16    270.01        -8.21
# 420549  31.12.2016 23:50:00    999.81     -4.23    268.94        -8.53
# 420550  01.01.2017 00:00:00    999.82     -4.82    268.36        -8.42
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# ...

# %%
#Pick every 6th 
df = df[5::6]
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 5       01.01.2009 01:00:00    996.50     -8.05    265.38        -8.78
# 11      01.01.2009 02:00:00    996.62     -8.88    264.54        -9.77
# 17      01.01.2009 03:00:00    996.84     -8.81    264.59        -9.66
# 23      01.01.2009 04:00:00    996.99     -9.05    264.34       -10.02
# 29      01.01.2009 05:00:00    997.46     -9.63    263.72       -10.65
# ...                     ...       ...       ...       ...          ...
# 420521  31.12.2016 19:10:00   1002.18     -0.98    272.01        -5.36
# 420527  31.12.2016 20:10:00   1001.40     -1.40    271.66        -6.84
# 420533  31.12.2016 21:10:00   1001.19     -2.75    270.32        -6.90
# 420539  31.12.2016 22:10:00   1000.65     -2.89    270.22        -7.15
# 420545  31.12.2016 23:10:00   1000.11     -3.93    269.23        -8.09
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# ...

# %%
df.index = pd.to_datetime(df['Date Time'], format ='%d.%m.%Y %H:%M:%S')
#displays first 26 rows
df[:26]
# Out:
#                                Date Time  p (mbar)  T (degC)  Tpot (K)  \
# Date Time
# 2009-01-01 01:00:00  01.01.2009 01:00:00    996.50     -8.05    265.38
# 2009-01-01 02:00:00  01.01.2009 02:00:00    996.62     -8.88    264.54
# 2009-01-01 03:00:00  01.01.2009 03:00:00    996.84     -8.81    264.59
# 2009-01-01 04:00:00  01.01.2009 04:00:00    996.99     -9.05    264.34
# 2009-01-01 05:00:00  01.01.2009 05:00:00    997.46     -9.63    263.72
# 2009-01-01 06:00:00  01.01.2009 06:00:00    997.71     -9.67    263.66
# 2009-01-01 07:00:00  01.01.2009 07:00:00    998.33     -9.17    264.12
# 2009-01-01 08:00:00  01.01.2009 08:00:00    999.17     -8.10    265.12
# 2009-01-01 09:00:00  01.01.2009 09:00:00    999.69     -7.66    265.52
# 2009-01-01 10:00:00  01.01.2009 10:00:00   1000.27     -7.04    266.10
# 2009-01-01 11:00:00  01.01.2009 11:00:00   1000.87     -7.41    265.68
# 2009-01-01 12:00:00  01.01.2009 12:00:00   1000.30     -6.87    266.27
# ...

# %%
temp = df['T (degC)']
temp.plot()
# Out:
# <Axes: xlabel='Date Time'>

# %%
def df_to_X_y(df, window_size=5):
    df_as_np = df.to_numpy() 
    X = []
    y = []
    for i in range(len(df_as_np)-window_size):
        row = [[a] for a in df_as_np[i:i+window_size]]
        X.append(row)
        label = df_as_np[i+5]
        y.append(label)
    return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 5
X,y = df_to_X_y(temp, WINDOW_SIZE)
X.shape, y.shape
# Out:
# ((70086, 5, 1), (70086,))

# %%
X_train, y_train = X[:60000], y[:60000]
X_val, y_val = X[60000:65000], y[60000:65000]
X_test, y_test = X[65000:], y[65000:]
X_train.shape, y_train.shape, X_val.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 5, 1), (60000,), (5000, 5, 1), (60000,), (5086, 5, 1), (5086,))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import mean_squared_error
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model1 = Sequential()
model1.add(InputLayer((5,1)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1,'linear'))
model1.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Admin\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 1)                 9
#
# ...
# Total params: 17425 (68.07 KB)
# Trainable params: 17425 (68.07 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cp = ModelCheckpoint('model1/', save_best_only=True)
model1.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model1.fit(X_train,y_train, validation_data=(X_val,y_val), epochs=10, callbacks=[cp])
# Out:
# Epoch 1/10
# WARNING:tensorflow:From C:\Users\Admin\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 1862/1875 [============================>.] - ETA: 0s - loss: 37.2854 - root_mean_squared_error: 6.1062INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 12s 5ms/step - loss: 37.0641 - root_mean_squared_error: 6.0880 - val_loss: 1.3493 - val_root_mean_squared_error: 1.1616
# Epoch 2/10
# 1870/1875 [============================>.] - ETA: 0s - loss: 2.4853 - root_mean_squared_error: 1.5765INFO:tensorflow:Assets written to: model1\assets
# INFO:tensorflow:Assets written to: model1\assets
# 1875/1875 [==============================] - 9s 5ms/step - loss: 2.4825 - root_mean_squared_error: 1.5756 - val_loss: 0.6199 - val_root_mean_squared_error: 0.7873
# Epoch 3/10
# ...

# %%
from tensorflow.keras.models import load_model
model1 = load_model('model1/')
# Out:
# WARNING:tensorflow:From C:\Users\Admin\anaconda3\Lib\site-packages\keras\src\saving\legacy\saved_model\load.py:107: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
# WARNING:tensorflow:From C:\Users\Admin\anaconda3\Lib\site-packages\keras\src\saving\legacy\saved_model\load.py:107: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.

# %%
train_predictions = model1.predict(X_train).flatten()
train_results = pd.DataFrame(data={'Train_predictions':train_predictions, 'Actuals': y_train})
train_results
# Out:
# 1875/1875 [==============================] - 4s 2ms/step
#        Train_predictions  Actuals
# 0              -9.813912    -9.67
# 1              -9.612542    -9.17
# 2              -8.730709    -8.10
# 3              -7.220659    -7.66
# 4              -7.076885    -7.04
# ...                  ...      ...
# 59995           6.112504     6.07
# 59996           7.175004     9.88
# 59997          12.038162    13.53
# 59998          15.712960    15.43
# 59999          16.289822    15.54
#
# [60000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(train_results['Train_predictions'])
plt.plot(train_results['Actuals'])

# %%
plt.plot(train_results['Train_predictions'][:100])
plt.plot(train_results['Actuals'][:100])

# %%
plt.plot(train_results['Train_predictions'][50:100])
plt.plot(train_results['Actuals'][50:100])

# %%
val_predictions = model1.predict(X_val).flatten()
val_results = pd.DataFrame(data={'val_predictions':val_predictions,'val_actuals':y_val})
val_results
# Out:
# 157/157 [==============================] - 1s 2ms/step
#       val_predictions  val_actuals
# 0           15.416676        14.02
# 1           13.193157        13.67
# 2           13.024042        12.27
# 3           11.421631        11.19
# 4           10.377929        10.85
# ...               ...          ...
# 4995        17.405190        18.27
# 4996        17.443485        17.85
# 4997        17.230303        16.65
# 4998        15.865049        15.85
# 4999        15.052774        15.09
#
# [5000 rows x 2 columns]

# %%
plt.plot(val_results['val_predictions'])
plt.plot(val_results['val_actuals'])

# %%
plt.plot(val_results['val_predictions'][:100])
plt.plot(val_results['val_actuals'][:100])

# %%
test_predictions = model1.predict(X_test).flatten() 
test_results = pd.DataFrame(data={'test_predictions':test_predictions,'test_actuals':y_test})
test_results
# Out:
# 159/159 [==============================] - 0s 2ms/step
#       test_predictions  test_actuals
# 0            14.352888         13.99
# 1            13.190242         13.46
# 2            12.847059         12.93
# 3            12.452862         12.43
# 4            12.021793         12.17
# ...                ...           ...
# 5081         -1.078761         -0.98
# 5082         -1.449600         -1.40
# 5083         -1.669574         -2.75
# 5084         -3.431440         -2.89
# 5085         -3.139271         -3.93
#
# [5086 rows x 2 columns]

# %%
plt.plot(test_results['test_predictions'][:100])
plt.plot(test_results['test_actuals'][:100])
